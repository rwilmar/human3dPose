# %%
# Converts the single-human-pose-estimation-0001 model to ONNX
import io
import numpy as np

from torch import nn
import torch.utils.model_zoo as model_zoo
import torch.onnx
from single_person_pose_with_mobilenet import SinglePersonPoseEstimationWithMobileNet

# %%
torch_model = SinglePersonPoseEstimationWithMobileNet()

# %%
MODEL_PATH = '../single-human-pose-estimation-0001.pth' 

# Initialize model with the pretrained weights
device = torch.device('cpu')
#map_location = lambda storage, loc: storage
if torch.cuda.is_available():
    device = None
torch_model.load_state_dict(torch.load(MODEL_PATH, map_location=device))

# set the model to inference mode
torch_model.eval()
# Out:
# SinglePersonPoseEstimationWithMobileNet(
#   (model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (6): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (7): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (8): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (9): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (10): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (11): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (cpm): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (initial_stage): InitialStage(
#     (trunk): Sequential(
#       (0): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (heatmaps): Sequential(
#       (0): Sequential(
#         (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(512, 17, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (refinement_stages): ModuleList(
#     (0): RefinementStage(
#       (trunk): Sequential(
#         (0): UShapedContextBlock(
#           (encoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(145, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (encoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(580, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(435, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 145, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(145, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (heatmaps): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 17, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (1): RefinementStage(
#       (trunk): Sequential(
#         (0): UShapedContextBlock(
#           (encoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(145, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (encoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(580, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(435, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 145, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(145, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (heatmaps): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 17, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (2): RefinementStage(
#       (trunk): Sequential(
#         (0): UShapedContextBlock(
#           (encoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(145, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (encoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(580, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(435, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 145, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(145, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (heatmaps): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 17, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (3): RefinementStage(
#       (trunk): Sequential(
#         (0): UShapedContextBlock(
#           (encoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(145, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (encoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(580, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(435, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 145, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(145, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (heatmaps): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 17, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (4): RefinementStage(
#       (trunk): Sequential(
#         (0): UShapedContextBlock(
#           (encoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(145, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (encoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder2): Sequential(
#             (0): Sequential(
#               (0): Conv2d(580, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#           (decoder1): Sequential(
#             (0): Sequential(
#               (0): Conv2d(435, 290, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(290, 145, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (1): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(145, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (2): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#         (3): RefinementStageBlock(
#           (initial): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (trunk): Sequential(
#             (0): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (heatmaps): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 17, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#   )
# )

# %%
# Input to the model    [1x3x384x288] - An input image in the format [BxCxHxW]
batch_size = 1   
x = torch.randn(1, 3, 384, 288)
torch_out = torch_model(x)

# %%
# Export the model
OUTMODEL_PATH = '../single-human-pose-estimation-0001.onnx'
torch.onnx.export(torch_model,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  OUTMODEL_PATH,             # where to save the model (can be a file or file-like object)
                  verbose=True,              # show results inline
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=9,           # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['data'],    # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'data' : {0 : 'batch_size'},    # variable lenght axes
                                'output' : {0 : 'batch_size'}})
#to later convert to OpenVino...
# /opt/intel/openvino/deployment_tools/model_optimizer/mo.py 
#--input_model models/single-human-pose-estimation-0001.onnx  --input_shape [1,3,384,288]
#--scale_values [58.395,57.12,57.375] --mean_values [123.675,116.28,103.53]  -o ./models/
# Out:
# graph(%data : Float(1, 3, 384, 288),
#       %model.0.0.weight : Float(32, 3, 3, 3),
#       %model.0.1.weight : Float(32),
#       %model.0.1.bias : Float(32),
#       %model.0.1.running_mean : Float(32),
#       %model.0.1.running_var : Float(32),
#       %model.1.0.weight : Float(32, 1, 3, 3),
#       %model.1.1.weight : Float(32),
#       %model.1.1.bias : Float(32),
#       %model.1.1.running_mean : Float(32),
#       %model.1.1.running_var : Float(32),
#       %model.1.3.weight : Float(64, 32, 1, 1),
#       %model.1.4.weight : Float(64),
#       %model.1.4.bias : Float(64),
#       %model.1.4.running_mean : Float(64),
#       %model.1.4.running_var : Float(64),
#       %model.2.0.weight : Float(64, 1, 3, 3),
#       %model.2.1.weight : Float(64),
#       %model.2.1.bias : Float(64),
#       %model.2.1.running_mean : Float(64),
#       %model.2.1.running_var : Float(64),
#       %model.2.3.weight : Float(128, 64, 1, 1),
#       %model.2.4.weight : Float(128),
#       %model.2.4.bias : Float(128),
#       %model.2.4.running_mean : Float(128),
#       %model.2.4.running_var : Float(128),
#       %model.3.0.weight : Float(128, 1, 3, 3),
#       %model.3.1.weight : Float(128),
#       %model.3.1.bias : Float(128),
#       %model.3.1.running_mean : Float(128),
#       %model.3.1.running_var : Float(128),
#       %model.3.3.weight : Float(128, 128, 1, 1),
#       %model.3.4.weight : Float(128),
#       %model.3.4.bias : Float(128),
#       %model.3.4.running_mean : Float(128),
#       %model.3.4.running_var : Float(128),
#       %model.4.0.weight : Float(128, 1, 3, 3),
#       %model.4.1.weight : Float(128),
#       %model.4.1.bias : Float(128),
#       %model.4.1.running_mean : Float(128),
#       %model.4.1.running_var : Float(128),
#       %model.4.3.weight : Float(256, 128, 1, 1),
#       %model.4.4.weight : Float(256),
#       %model.4.4.bias : Float(256),
#       %model.4.4.running_mean : Float(256),
#       %model.4.4.running_var : Float(256),
#       %model.5.0.weight : Float(256, 1, 3, 3),
#       %model.5.1.weight : Float(256),
#       %model.5.1.bias : Float(256),
#       %model.5.1.running_mean : Float(256),
#       %model.5.1.running_var : Float(256),
#       %model.5.3.weight : Float(256, 256, 1, 1),
#       %model.5.4.weight : Float(256),
#       %model.5.4.bias : Float(256),
#       %model.5.4.running_mean : Float(256),
#       %model.5.4.running_var : Float(256),
#       %model.6.0.weight : Float(256, 1, 3, 3),
#       %model.6.1.weight : Float(256),
#       %model.6.1.bias : Float(256),
#       %model.6.1.running_mean : Float(256),
#       %model.6.1.running_var : Float(256),
#       %model.6.3.weight : Float(512, 256, 1, 1),
#       %model.6.4.weight : Float(512),
#       %model.6.4.bias : Float(512),
#       %model.6.4.running_mean : Float(512),
#       %model.6.4.running_var : Float(512),
#       %model.7.0.weight : Float(512, 1, 3, 3),
#       %model.7.1.weight : Float(512),
#       %model.7.1.bias : Float(512),
#       %model.7.1.running_mean : Float(512),
#       %model.7.1.running_var : Float(512),
#       %model.7.3.weight : Float(512, 512, 1, 1),
#       %model.7.4.weight : Float(512),
#       %model.7.4.bias : Float(512),
#       %model.7.4.running_mean : Float(512),
#       %model.7.4.running_var : Float(512),
#       %model.8.0.weight : Float(512, 1, 3, 3),
#       %model.8.1.weight : Float(512),
#       %model.8.1.bias : Float(512),
#       %model.8.1.running_mean : Float(512),
#       %model.8.1.running_var : Float(512),
#       %model.8.3.weight : Float(512, 512, 1, 1),
#       %model.8.4.weight : Float(512),
#       %model.8.4.bias : Float(512),
#       %model.8.4.running_mean : Float(512),
#       %model.8.4.running_var : Float(512),
#       %model.9.0.weight : Float(512, 1, 3, 3),
#       %model.9.1.weight : Float(512),
#       %model.9.1.bias : Float(512),
#       %model.9.1.running_mean : Float(512),
#       %model.9.1.running_var : Float(512),
#       %model.9.3.weight : Float(512, 512, 1, 1),
#       %model.9.4.weight : Float(512),
#       %model.9.4.bias : Float(512),
#       %model.9.4.running_mean : Float(512),
#       %model.9.4.running_var : Float(512),
#       %model.10.0.weight : Float(512, 1, 3, 3),
#       %model.10.1.weight : Float(512),
#       %model.10.1.bias : Float(512),
#       %model.10.1.running_mean : Float(512),
#       %model.10.1.running_var : Float(512),
#       %model.10.3.weight : Float(512, 512, 1, 1),
#       %model.10.4.weight : Float(512),
#       %model.10.4.bias : Float(512),
#       %model.10.4.running_mean : Float(512),
#       %model.10.4.running_var : Float(512),
#       %model.11.0.weight : Float(512, 1, 3, 3),
#       %model.11.1.weight : Float(512),
#       %model.11.1.bias : Float(512),
#       %model.11.1.running_mean : Float(512),
#       %model.11.1.running_var : Float(512),
#       %model.11.3.weight : Float(512, 512, 1, 1),
#       %model.11.4.weight : Float(512),
#       %model.11.4.bias : Float(512),
#       %model.11.4.running_mean : Float(512),
#       %model.11.4.running_var : Float(512),
#       %cpm.0.0.weight : Float(256, 512, 3, 3),
#       %cpm.0.0.bias : Float(256),
#       %cpm.0.1.weight : Float(256),
#       %cpm.0.1.bias : Float(256),
#       %cpm.0.1.running_mean : Float(256),
#       %cpm.0.1.running_var : Float(256),
#       %cpm.1.0.weight : Float(128, 256, 3, 3),
#       %cpm.1.0.bias : Float(128),
#       %cpm.1.1.weight : Float(128),
#       %cpm.1.1.bias : Float(128),
#       %cpm.1.1.running_mean : Float(128),
#       %cpm.1.1.running_var : Float(128),
#       %initial_stage.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %initial_stage.trunk.0.0.bias : Float(128),
#       %initial_stage.trunk.0.1.weight : Float(128),
#       %initial_stage.trunk.0.1.bias : Float(128),
#       %initial_stage.trunk.0.1.running_mean : Float(128),
#       %initial_stage.trunk.0.1.running_var : Float(128),
#       %initial_stage.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %initial_stage.trunk.1.0.bias : Float(128),
#       %initial_stage.trunk.1.1.weight : Float(128),
#       %initial_stage.trunk.1.1.bias : Float(128),
#       %initial_stage.trunk.1.1.running_mean : Float(128),
#       %initial_stage.trunk.1.1.running_var : Float(128),
#       %initial_stage.trunk.2.0.weight : Float(128, 128, 3, 3),
#       %initial_stage.trunk.2.0.bias : Float(128),
#       %initial_stage.trunk.2.1.weight : Float(128),
#       %initial_stage.trunk.2.1.bias : Float(128),
#       %initial_stage.trunk.2.1.running_mean : Float(128),
#       %initial_stage.trunk.2.1.running_var : Float(128),
#       %initial_stage.heatmaps.0.0.weight : Float(512, 128, 1, 1),
#       %initial_stage.heatmaps.0.0.bias : Float(512),
#       %initial_stage.heatmaps.1.0.weight : Float(17, 512, 1, 1),
#       %initial_stage.heatmaps.1.0.bias : Float(17),
#       %refinement_stages.0.trunk.0.encoder1.0.0.weight : Float(290, 145, 3, 3),
#       %refinement_stages.0.trunk.0.encoder1.0.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.0.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.0.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.0.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.0.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.0.trunk.0.encoder1.1.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.1.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.1.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.1.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.encoder1.1.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.0.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.0.trunk.0.encoder2.0.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.0.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.0.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.0.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.0.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.0.trunk.0.encoder2.1.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.1.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.1.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.1.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.encoder2.1.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.0.0.weight : Float(290, 580, 3, 3),
#       %refinement_stages.0.trunk.0.decoder2.0.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.0.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.0.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.0.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.0.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.0.trunk.0.decoder2.1.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.1.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.1.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.1.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.decoder2.1.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.0.0.weight : Float(290, 435, 3, 3),
#       %refinement_stages.0.trunk.0.decoder1.0.0.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.0.1.weight : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.0.1.bias : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.0.1.running_mean : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.0.1.running_var : Float(290),
#       %refinement_stages.0.trunk.0.decoder1.1.0.weight : Float(145, 290, 3, 3),
#       %refinement_stages.0.trunk.0.decoder1.1.0.bias : Float(145),
#       %refinement_stages.0.trunk.0.decoder1.1.1.weight : Float(145),
#       %refinement_stages.0.trunk.0.decoder1.1.1.bias : Float(145),
#       %refinement_stages.0.trunk.0.decoder1.1.1.running_mean : Float(145),
#       %refinement_stages.0.trunk.0.decoder1.1.1.running_var : Float(145),
#       %refinement_stages.0.trunk.1.initial.0.weight : Float(128, 145, 1, 1),
#       %refinement_stages.0.trunk.1.initial.0.bias : Float(128),
#       %refinement_stages.0.trunk.1.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.1.trunk.0.0.bias : Float(128),
#       %refinement_stages.0.trunk.1.trunk.0.1.weight : Float(128),
#       %refinement_stages.0.trunk.1.trunk.0.1.bias : Float(128),
#       %refinement_stages.0.trunk.1.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.1.trunk.0.1.running_var : Float(128),
#       %refinement_stages.0.trunk.1.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.1.trunk.1.0.bias : Float(128),
#       %refinement_stages.0.trunk.1.trunk.1.1.weight : Float(128),
#       %refinement_stages.0.trunk.1.trunk.1.1.bias : Float(128),
#       %refinement_stages.0.trunk.1.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.1.trunk.1.1.running_var : Float(128),
#       %refinement_stages.0.trunk.2.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.0.trunk.2.initial.0.bias : Float(128),
#       %refinement_stages.0.trunk.2.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.2.trunk.0.0.bias : Float(128),
#       %refinement_stages.0.trunk.2.trunk.0.1.weight : Float(128),
#       %refinement_stages.0.trunk.2.trunk.0.1.bias : Float(128),
#       %refinement_stages.0.trunk.2.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.2.trunk.0.1.running_var : Float(128),
#       %refinement_stages.0.trunk.2.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.2.trunk.1.0.bias : Float(128),
#       %refinement_stages.0.trunk.2.trunk.1.1.weight : Float(128),
#       %refinement_stages.0.trunk.2.trunk.1.1.bias : Float(128),
#       %refinement_stages.0.trunk.2.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.2.trunk.1.1.running_var : Float(128),
#       %refinement_stages.0.trunk.3.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.0.trunk.3.initial.0.bias : Float(128),
#       %refinement_stages.0.trunk.3.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.3.trunk.0.0.bias : Float(128),
#       %refinement_stages.0.trunk.3.trunk.0.1.weight : Float(128),
#       %refinement_stages.0.trunk.3.trunk.0.1.bias : Float(128),
#       %refinement_stages.0.trunk.3.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.3.trunk.0.1.running_var : Float(128),
#       %refinement_stages.0.trunk.3.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.0.trunk.3.trunk.1.0.bias : Float(128),
#       %refinement_stages.0.trunk.3.trunk.1.1.weight : Float(128),
#       %refinement_stages.0.trunk.3.trunk.1.1.bias : Float(128),
#       %refinement_stages.0.trunk.3.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.0.trunk.3.trunk.1.1.running_var : Float(128),
#       %refinement_stages.0.heatmaps.0.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.0.heatmaps.0.0.bias : Float(128),
#       %refinement_stages.0.heatmaps.1.0.weight : Float(17, 128, 1, 1),
#       %refinement_stages.0.heatmaps.1.0.bias : Float(17),
#       %refinement_stages.1.trunk.0.encoder1.0.0.weight : Float(290, 145, 3, 3),
#       %refinement_stages.1.trunk.0.encoder1.0.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.0.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.0.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.0.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.0.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.1.trunk.0.encoder1.1.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.1.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.1.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.1.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.encoder1.1.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.0.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.1.trunk.0.encoder2.0.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.0.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.0.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.0.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.0.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.1.trunk.0.encoder2.1.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.1.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.1.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.1.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.encoder2.1.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.0.0.weight : Float(290, 580, 3, 3),
#       %refinement_stages.1.trunk.0.decoder2.0.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.0.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.0.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.0.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.0.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.1.trunk.0.decoder2.1.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.1.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.1.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.1.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.decoder2.1.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.0.0.weight : Float(290, 435, 3, 3),
#       %refinement_stages.1.trunk.0.decoder1.0.0.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.0.1.weight : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.0.1.bias : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.0.1.running_mean : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.0.1.running_var : Float(290),
#       %refinement_stages.1.trunk.0.decoder1.1.0.weight : Float(145, 290, 3, 3),
#       %refinement_stages.1.trunk.0.decoder1.1.0.bias : Float(145),
#       %refinement_stages.1.trunk.0.decoder1.1.1.weight : Float(145),
#       %refinement_stages.1.trunk.0.decoder1.1.1.bias : Float(145),
#       %refinement_stages.1.trunk.0.decoder1.1.1.running_mean : Float(145),
#       %refinement_stages.1.trunk.0.decoder1.1.1.running_var : Float(145),
#       %refinement_stages.1.trunk.1.initial.0.weight : Float(128, 145, 1, 1),
#       %refinement_stages.1.trunk.1.initial.0.bias : Float(128),
#       %refinement_stages.1.trunk.1.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.1.trunk.0.0.bias : Float(128),
#       %refinement_stages.1.trunk.1.trunk.0.1.weight : Float(128),
#       %refinement_stages.1.trunk.1.trunk.0.1.bias : Float(128),
#       %refinement_stages.1.trunk.1.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.1.trunk.0.1.running_var : Float(128),
#       %refinement_stages.1.trunk.1.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.1.trunk.1.0.bias : Float(128),
#       %refinement_stages.1.trunk.1.trunk.1.1.weight : Float(128),
#       %refinement_stages.1.trunk.1.trunk.1.1.bias : Float(128),
#       %refinement_stages.1.trunk.1.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.1.trunk.1.1.running_var : Float(128),
#       %refinement_stages.1.trunk.2.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.1.trunk.2.initial.0.bias : Float(128),
#       %refinement_stages.1.trunk.2.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.2.trunk.0.0.bias : Float(128),
#       %refinement_stages.1.trunk.2.trunk.0.1.weight : Float(128),
#       %refinement_stages.1.trunk.2.trunk.0.1.bias : Float(128),
#       %refinement_stages.1.trunk.2.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.2.trunk.0.1.running_var : Float(128),
#       %refinement_stages.1.trunk.2.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.2.trunk.1.0.bias : Float(128),
#       %refinement_stages.1.trunk.2.trunk.1.1.weight : Float(128),
#       %refinement_stages.1.trunk.2.trunk.1.1.bias : Float(128),
#       %refinement_stages.1.trunk.2.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.2.trunk.1.1.running_var : Float(128),
#       %refinement_stages.1.trunk.3.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.1.trunk.3.initial.0.bias : Float(128),
#       %refinement_stages.1.trunk.3.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.3.trunk.0.0.bias : Float(128),
#       %refinement_stages.1.trunk.3.trunk.0.1.weight : Float(128),
#       %refinement_stages.1.trunk.3.trunk.0.1.bias : Float(128),
#       %refinement_stages.1.trunk.3.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.3.trunk.0.1.running_var : Float(128),
#       %refinement_stages.1.trunk.3.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.1.trunk.3.trunk.1.0.bias : Float(128),
#       %refinement_stages.1.trunk.3.trunk.1.1.weight : Float(128),
#       %refinement_stages.1.trunk.3.trunk.1.1.bias : Float(128),
#       %refinement_stages.1.trunk.3.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.1.trunk.3.trunk.1.1.running_var : Float(128),
#       %refinement_stages.1.heatmaps.0.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.1.heatmaps.0.0.bias : Float(128),
#       %refinement_stages.1.heatmaps.1.0.weight : Float(17, 128, 1, 1),
#       %refinement_stages.1.heatmaps.1.0.bias : Float(17),
#       %refinement_stages.2.trunk.0.encoder1.0.0.weight : Float(290, 145, 3, 3),
#       %refinement_stages.2.trunk.0.encoder1.0.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.0.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.0.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.0.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.0.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.2.trunk.0.encoder1.1.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.1.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.1.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.1.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.encoder1.1.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.0.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.2.trunk.0.encoder2.0.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.0.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.0.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.0.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.0.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.2.trunk.0.encoder2.1.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.1.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.1.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.1.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.encoder2.1.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.0.0.weight : Float(290, 580, 3, 3),
#       %refinement_stages.2.trunk.0.decoder2.0.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.0.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.0.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.0.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.0.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.2.trunk.0.decoder2.1.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.1.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.1.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.1.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.decoder2.1.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.0.0.weight : Float(290, 435, 3, 3),
#       %refinement_stages.2.trunk.0.decoder1.0.0.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.0.1.weight : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.0.1.bias : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.0.1.running_mean : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.0.1.running_var : Float(290),
#       %refinement_stages.2.trunk.0.decoder1.1.0.weight : Float(145, 290, 3, 3),
#       %refinement_stages.2.trunk.0.decoder1.1.0.bias : Float(145),
#       %refinement_stages.2.trunk.0.decoder1.1.1.weight : Float(145),
#       %refinement_stages.2.trunk.0.decoder1.1.1.bias : Float(145),
#       %refinement_stages.2.trunk.0.decoder1.1.1.running_mean : Float(145),
#       %refinement_stages.2.trunk.0.decoder1.1.1.running_var : Float(145),
#       %refinement_stages.2.trunk.1.initial.0.weight : Float(128, 145, 1, 1),
#       %refinement_stages.2.trunk.1.initial.0.bias : Float(128),
#       %refinement_stages.2.trunk.1.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.1.trunk.0.0.bias : Float(128),
#       %refinement_stages.2.trunk.1.trunk.0.1.weight : Float(128),
#       %refinement_stages.2.trunk.1.trunk.0.1.bias : Float(128),
#       %refinement_stages.2.trunk.1.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.1.trunk.0.1.running_var : Float(128),
#       %refinement_stages.2.trunk.1.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.1.trunk.1.0.bias : Float(128),
#       %refinement_stages.2.trunk.1.trunk.1.1.weight : Float(128),
#       %refinement_stages.2.trunk.1.trunk.1.1.bias : Float(128),
#       %refinement_stages.2.trunk.1.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.1.trunk.1.1.running_var : Float(128),
#       %refinement_stages.2.trunk.2.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.2.trunk.2.initial.0.bias : Float(128),
#       %refinement_stages.2.trunk.2.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.2.trunk.0.0.bias : Float(128),
#       %refinement_stages.2.trunk.2.trunk.0.1.weight : Float(128),
#       %refinement_stages.2.trunk.2.trunk.0.1.bias : Float(128),
#       %refinement_stages.2.trunk.2.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.2.trunk.0.1.running_var : Float(128),
#       %refinement_stages.2.trunk.2.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.2.trunk.1.0.bias : Float(128),
#       %refinement_stages.2.trunk.2.trunk.1.1.weight : Float(128),
#       %refinement_stages.2.trunk.2.trunk.1.1.bias : Float(128),
#       %refinement_stages.2.trunk.2.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.2.trunk.1.1.running_var : Float(128),
#       %refinement_stages.2.trunk.3.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.2.trunk.3.initial.0.bias : Float(128),
#       %refinement_stages.2.trunk.3.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.3.trunk.0.0.bias : Float(128),
#       %refinement_stages.2.trunk.3.trunk.0.1.weight : Float(128),
#       %refinement_stages.2.trunk.3.trunk.0.1.bias : Float(128),
#       %refinement_stages.2.trunk.3.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.3.trunk.0.1.running_var : Float(128),
#       %refinement_stages.2.trunk.3.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.2.trunk.3.trunk.1.0.bias : Float(128),
#       %refinement_stages.2.trunk.3.trunk.1.1.weight : Float(128),
#       %refinement_stages.2.trunk.3.trunk.1.1.bias : Float(128),
#       %refinement_stages.2.trunk.3.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.2.trunk.3.trunk.1.1.running_var : Float(128),
#       %refinement_stages.2.heatmaps.0.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.2.heatmaps.0.0.bias : Float(128),
#       %refinement_stages.2.heatmaps.1.0.weight : Float(17, 128, 1, 1),
#       %refinement_stages.2.heatmaps.1.0.bias : Float(17),
#       %refinement_stages.3.trunk.0.encoder1.0.0.weight : Float(290, 145, 3, 3),
#       %refinement_stages.3.trunk.0.encoder1.0.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.0.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.0.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.0.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.0.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.3.trunk.0.encoder1.1.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.1.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.1.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.1.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.encoder1.1.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.0.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.3.trunk.0.encoder2.0.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.0.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.0.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.0.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.0.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.3.trunk.0.encoder2.1.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.1.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.1.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.1.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.encoder2.1.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.0.0.weight : Float(290, 580, 3, 3),
#       %refinement_stages.3.trunk.0.decoder2.0.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.0.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.0.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.0.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.0.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.3.trunk.0.decoder2.1.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.1.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.1.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.1.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.decoder2.1.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.0.0.weight : Float(290, 435, 3, 3),
#       %refinement_stages.3.trunk.0.decoder1.0.0.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.0.1.weight : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.0.1.bias : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.0.1.running_mean : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.0.1.running_var : Float(290),
#       %refinement_stages.3.trunk.0.decoder1.1.0.weight : Float(145, 290, 3, 3),
#       %refinement_stages.3.trunk.0.decoder1.1.0.bias : Float(145),
#       %refinement_stages.3.trunk.0.decoder1.1.1.weight : Float(145),
#       %refinement_stages.3.trunk.0.decoder1.1.1.bias : Float(145),
#       %refinement_stages.3.trunk.0.decoder1.1.1.running_mean : Float(145),
#       %refinement_stages.3.trunk.0.decoder1.1.1.running_var : Float(145),
#       %refinement_stages.3.trunk.1.initial.0.weight : Float(128, 145, 1, 1),
#       %refinement_stages.3.trunk.1.initial.0.bias : Float(128),
#       %refinement_stages.3.trunk.1.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.1.trunk.0.0.bias : Float(128),
#       %refinement_stages.3.trunk.1.trunk.0.1.weight : Float(128),
#       %refinement_stages.3.trunk.1.trunk.0.1.bias : Float(128),
#       %refinement_stages.3.trunk.1.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.1.trunk.0.1.running_var : Float(128),
#       %refinement_stages.3.trunk.1.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.1.trunk.1.0.bias : Float(128),
#       %refinement_stages.3.trunk.1.trunk.1.1.weight : Float(128),
#       %refinement_stages.3.trunk.1.trunk.1.1.bias : Float(128),
#       %refinement_stages.3.trunk.1.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.1.trunk.1.1.running_var : Float(128),
#       %refinement_stages.3.trunk.2.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.3.trunk.2.initial.0.bias : Float(128),
#       %refinement_stages.3.trunk.2.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.2.trunk.0.0.bias : Float(128),
#       %refinement_stages.3.trunk.2.trunk.0.1.weight : Float(128),
#       %refinement_stages.3.trunk.2.trunk.0.1.bias : Float(128),
#       %refinement_stages.3.trunk.2.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.2.trunk.0.1.running_var : Float(128),
#       %refinement_stages.3.trunk.2.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.2.trunk.1.0.bias : Float(128),
#       %refinement_stages.3.trunk.2.trunk.1.1.weight : Float(128),
#       %refinement_stages.3.trunk.2.trunk.1.1.bias : Float(128),
#       %refinement_stages.3.trunk.2.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.2.trunk.1.1.running_var : Float(128),
#       %refinement_stages.3.trunk.3.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.3.trunk.3.initial.0.bias : Float(128),
#       %refinement_stages.3.trunk.3.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.3.trunk.0.0.bias : Float(128),
#       %refinement_stages.3.trunk.3.trunk.0.1.weight : Float(128),
#       %refinement_stages.3.trunk.3.trunk.0.1.bias : Float(128),
#       %refinement_stages.3.trunk.3.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.3.trunk.0.1.running_var : Float(128),
#       %refinement_stages.3.trunk.3.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.3.trunk.3.trunk.1.0.bias : Float(128),
#       %refinement_stages.3.trunk.3.trunk.1.1.weight : Float(128),
#       %refinement_stages.3.trunk.3.trunk.1.1.bias : Float(128),
#       %refinement_stages.3.trunk.3.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.3.trunk.3.trunk.1.1.running_var : Float(128),
#       %refinement_stages.3.heatmaps.0.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.3.heatmaps.0.0.bias : Float(128),
#       %refinement_stages.3.heatmaps.1.0.weight : Float(17, 128, 1, 1),
#       %refinement_stages.3.heatmaps.1.0.bias : Float(17),
#       %refinement_stages.4.trunk.0.encoder1.0.0.weight : Float(290, 145, 3, 3),
#       %refinement_stages.4.trunk.0.encoder1.0.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.0.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.0.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.0.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.0.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.4.trunk.0.encoder1.1.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.1.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.1.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.1.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.encoder1.1.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.0.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.4.trunk.0.encoder2.0.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.0.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.0.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.0.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.0.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.4.trunk.0.encoder2.1.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.1.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.1.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.1.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.encoder2.1.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.0.0.weight : Float(290, 580, 3, 3),
#       %refinement_stages.4.trunk.0.decoder2.0.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.0.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.0.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.0.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.0.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.1.0.weight : Float(290, 290, 3, 3),
#       %refinement_stages.4.trunk.0.decoder2.1.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.1.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.1.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.1.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.decoder2.1.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.0.0.weight : Float(290, 435, 3, 3),
#       %refinement_stages.4.trunk.0.decoder1.0.0.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.0.1.weight : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.0.1.bias : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.0.1.running_mean : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.0.1.running_var : Float(290),
#       %refinement_stages.4.trunk.0.decoder1.1.0.weight : Float(145, 290, 3, 3),
#       %refinement_stages.4.trunk.0.decoder1.1.0.bias : Float(145),
#       %refinement_stages.4.trunk.0.decoder1.1.1.weight : Float(145),
#       %refinement_stages.4.trunk.0.decoder1.1.1.bias : Float(145),
#       %refinement_stages.4.trunk.0.decoder1.1.1.running_mean : Float(145),
#       %refinement_stages.4.trunk.0.decoder1.1.1.running_var : Float(145),
#       %refinement_stages.4.trunk.1.initial.0.weight : Float(128, 145, 1, 1),
#       %refinement_stages.4.trunk.1.initial.0.bias : Float(128),
#       %refinement_stages.4.trunk.1.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.1.trunk.0.0.bias : Float(128),
#       %refinement_stages.4.trunk.1.trunk.0.1.weight : Float(128),
#       %refinement_stages.4.trunk.1.trunk.0.1.bias : Float(128),
#       %refinement_stages.4.trunk.1.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.1.trunk.0.1.running_var : Float(128),
#       %refinement_stages.4.trunk.1.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.1.trunk.1.0.bias : Float(128),
#       %refinement_stages.4.trunk.1.trunk.1.1.weight : Float(128),
#       %refinement_stages.4.trunk.1.trunk.1.1.bias : Float(128),
#       %refinement_stages.4.trunk.1.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.1.trunk.1.1.running_var : Float(128),
#       %refinement_stages.4.trunk.2.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.4.trunk.2.initial.0.bias : Float(128),
#       %refinement_stages.4.trunk.2.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.2.trunk.0.0.bias : Float(128),
#       %refinement_stages.4.trunk.2.trunk.0.1.weight : Float(128),
#       %refinement_stages.4.trunk.2.trunk.0.1.bias : Float(128),
#       %refinement_stages.4.trunk.2.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.2.trunk.0.1.running_var : Float(128),
#       %refinement_stages.4.trunk.2.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.2.trunk.1.0.bias : Float(128),
#       %refinement_stages.4.trunk.2.trunk.1.1.weight : Float(128),
#       %refinement_stages.4.trunk.2.trunk.1.1.bias : Float(128),
#       %refinement_stages.4.trunk.2.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.2.trunk.1.1.running_var : Float(128),
#       %refinement_stages.4.trunk.3.initial.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.4.trunk.3.initial.0.bias : Float(128),
#       %refinement_stages.4.trunk.3.trunk.0.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.3.trunk.0.0.bias : Float(128),
#       %refinement_stages.4.trunk.3.trunk.0.1.weight : Float(128),
#       %refinement_stages.4.trunk.3.trunk.0.1.bias : Float(128),
#       %refinement_stages.4.trunk.3.trunk.0.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.3.trunk.0.1.running_var : Float(128),
#       %refinement_stages.4.trunk.3.trunk.1.0.weight : Float(128, 128, 3, 3),
#       %refinement_stages.4.trunk.3.trunk.1.0.bias : Float(128),
#       %refinement_stages.4.trunk.3.trunk.1.1.weight : Float(128),
#       %refinement_stages.4.trunk.3.trunk.1.1.bias : Float(128),
#       %refinement_stages.4.trunk.3.trunk.1.1.running_mean : Float(128),
#       %refinement_stages.4.trunk.3.trunk.1.1.running_var : Float(128),
#       %refinement_stages.4.heatmaps.0.0.weight : Float(128, 128, 1, 1),
#       %refinement_stages.4.heatmaps.0.0.bias : Float(128),
#       %refinement_stages.4.heatmaps.1.0.weight : Float(17, 128, 1, 1),
#       %refinement_stages.4.heatmaps.1.0.bias : Float(17)):
#   %718 : Float(1, 32, 192, 144) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%data, %model.0.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %719 : Float(1, 32, 192, 144) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%718, %model.0.1.weight, %model.0.1.bias, %model.0.1.running_mean, %model.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %720 : Float(1, 32, 192, 144) = onnx::Relu(%719) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %721 : Float(1, 32, 192, 144) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%720, %model.1.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %722 : Float(1, 32, 192, 144) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%721, %model.1.1.weight, %model.1.1.bias, %model.1.1.running_mean, %model.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %723 : Float(1, 32, 192, 144) = onnx::Relu(%722) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %724 : Float(1, 64, 192, 144) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%723, %model.1.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %725 : Float(1, 64, 192, 144) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%724, %model.1.4.weight, %model.1.4.bias, %model.1.4.running_mean, %model.1.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %726 : Float(1, 64, 192, 144) = onnx::Relu(%725) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %727 : Float(1, 64, 96, 72) = onnx::Conv[dilations=[1, 1], group=64, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%726, %model.2.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %728 : Float(1, 64, 96, 72) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%727, %model.2.1.weight, %model.2.1.bias, %model.2.1.running_mean, %model.2.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %729 : Float(1, 64, 96, 72) = onnx::Relu(%728) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %730 : Float(1, 128, 96, 72) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%729, %model.2.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %731 : Float(1, 128, 96, 72) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%730, %model.2.4.weight, %model.2.4.bias, %model.2.4.running_mean, %model.2.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %732 : Float(1, 128, 96, 72) = onnx::Relu(%731) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %733 : Float(1, 128, 96, 72) = onnx::Conv[dilations=[1, 1], group=128, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%732, %model.3.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %734 : Float(1, 128, 96, 72) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%733, %model.3.1.weight, %model.3.1.bias, %model.3.1.running_mean, %model.3.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %735 : Float(1, 128, 96, 72) = onnx::Relu(%734) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %736 : Float(1, 128, 96, 72) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%735, %model.3.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %737 : Float(1, 128, 96, 72) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%736, %model.3.4.weight, %model.3.4.bias, %model.3.4.running_mean, %model.3.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %738 : Float(1, 128, 96, 72) = onnx::Relu(%737) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %739 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=128, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%738, %model.4.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %740 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%739, %model.4.1.weight, %model.4.1.bias, %model.4.1.running_mean, %model.4.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %741 : Float(1, 128, 48, 36) = onnx::Relu(%740) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %742 : Float(1, 256, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%741, %model.4.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %743 : Float(1, 256, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%742, %model.4.4.weight, %model.4.4.bias, %model.4.4.running_mean, %model.4.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %744 : Float(1, 256, 48, 36) = onnx::Relu(%743) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %745 : Float(1, 256, 48, 36) = onnx::Conv[dilations=[1, 1], group=256, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%744, %model.5.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %746 : Float(1, 256, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%745, %model.5.1.weight, %model.5.1.bias, %model.5.1.running_mean, %model.5.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %747 : Float(1, 256, 48, 36) = onnx::Relu(%746) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %748 : Float(1, 256, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%747, %model.5.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %749 : Float(1, 256, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%748, %model.5.4.weight, %model.5.4.bias, %model.5.4.running_mean, %model.5.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %750 : Float(1, 256, 48, 36) = onnx::Relu(%749) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %751 : Float(1, 256, 48, 36) = onnx::Conv[dilations=[1, 1], group=256, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%750, %model.6.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %752 : Float(1, 256, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%751, %model.6.1.weight, %model.6.1.bias, %model.6.1.running_mean, %model.6.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %753 : Float(1, 256, 48, 36) = onnx::Relu(%752) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %754 : Float(1, 512, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%753, %model.6.3.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %755 : Float(1, 512, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%754, %model.6.4.weight, %model.6.4.bias, %model.6.4.running_mean, %model.6.4.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %756 : Float(1, 512, 48, 36) = onnx::Relu(%755) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %757 : Float(1, 512, 48, 36) = onnx::Conv[dilations=[2, 2], group=512, kernel_shape=[3, 3], pads=[2, 2, 2, 2], strides=[1, 1]](%756, %model.7.0.weight) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
# ...
#   %1044 : Float(1, 128, 48, 36) = onnx::Relu(%1043) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1045 : Float(1, 128, 48, 36) = onnx::Add(%1038, %1044) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/with_mobilenet.py:60:0
#   %1046 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1045, %refinement_stages.3.heatmaps.0.0.weight, %refinement_stages.3.heatmaps.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1047 : Float(1, 128, 48, 36) = onnx::Relu(%1046) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1048 : Float(1, 17, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1047, %refinement_stages.3.heatmaps.1.0.weight, %refinement_stages.3.heatmaps.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1049 : Float(1, 145, 48, 36) = onnx::Concat[axis=1](%792, %1048) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/single_person_pose_with_mobilenet.py:113:0
#   %1050 : Float(1, 290, 24, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%1049, %refinement_stages.4.trunk.0.encoder1.0.0.weight, %refinement_stages.4.trunk.0.encoder1.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1051 : Float(1, 290, 24, 18) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1050, %refinement_stages.4.trunk.0.encoder1.0.1.weight, %refinement_stages.4.trunk.0.encoder1.0.1.bias, %refinement_stages.4.trunk.0.encoder1.0.1.running_mean, %refinement_stages.4.trunk.0.encoder1.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1052 : Float(1, 290, 24, 18) = onnx::Relu(%1051) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1053 : Float(1, 290, 24, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1052, %refinement_stages.4.trunk.0.encoder1.1.0.weight, %refinement_stages.4.trunk.0.encoder1.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1054 : Float(1, 290, 24, 18) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1053, %refinement_stages.4.trunk.0.encoder1.1.1.weight, %refinement_stages.4.trunk.0.encoder1.1.1.bias, %refinement_stages.4.trunk.0.encoder1.1.1.running_mean, %refinement_stages.4.trunk.0.encoder1.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1055 : Float(1, 290, 24, 18) = onnx::Relu(%1054) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1056 : Float(1, 290, 12, 9) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%1055, %refinement_stages.4.trunk.0.encoder2.0.0.weight, %refinement_stages.4.trunk.0.encoder2.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1057 : Float(1, 290, 12, 9) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1056, %refinement_stages.4.trunk.0.encoder2.0.1.weight, %refinement_stages.4.trunk.0.encoder2.0.1.bias, %refinement_stages.4.trunk.0.encoder2.0.1.running_mean, %refinement_stages.4.trunk.0.encoder2.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1058 : Float(1, 290, 12, 9) = onnx::Relu(%1057) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1059 : Float(1, 290, 12, 9) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1058, %refinement_stages.4.trunk.0.encoder2.1.0.weight, %refinement_stages.4.trunk.0.encoder2.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1060 : Float(1, 290, 12, 9) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1059, %refinement_stages.4.trunk.0.encoder2.1.1.weight, %refinement_stages.4.trunk.0.encoder2.1.1.bias, %refinement_stages.4.trunk.0.encoder2.1.1.running_mean, %refinement_stages.4.trunk.0.encoder2.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1061 : Float(1, 290, 12, 9) = onnx::Relu(%1060) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1062 : Tensor = onnx::Constant[value= 1  1  2  2 [ CPUFloatType{4} ]]()
#   %1063 : Float(1, 290, 24, 18) = onnx::Upsample[mode="nearest"](%1061, %1062) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2512:0
#   %1064 : Float(1, 580, 24, 18) = onnx::Concat[axis=1](%1055, %1063) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/single_person_pose_with_mobilenet.py:52:0
#   %1065 : Float(1, 290, 24, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1064, %refinement_stages.4.trunk.0.decoder2.0.0.weight, %refinement_stages.4.trunk.0.decoder2.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1066 : Float(1, 290, 24, 18) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1065, %refinement_stages.4.trunk.0.decoder2.0.1.weight, %refinement_stages.4.trunk.0.decoder2.0.1.bias, %refinement_stages.4.trunk.0.decoder2.0.1.running_mean, %refinement_stages.4.trunk.0.decoder2.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1067 : Float(1, 290, 24, 18) = onnx::Relu(%1066) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1068 : Float(1, 290, 24, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1067, %refinement_stages.4.trunk.0.decoder2.1.0.weight, %refinement_stages.4.trunk.0.decoder2.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1069 : Float(1, 290, 24, 18) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1068, %refinement_stages.4.trunk.0.decoder2.1.1.weight, %refinement_stages.4.trunk.0.decoder2.1.1.bias, %refinement_stages.4.trunk.0.decoder2.1.1.running_mean, %refinement_stages.4.trunk.0.decoder2.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1070 : Float(1, 290, 24, 18) = onnx::Relu(%1069) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1071 : Tensor = onnx::Constant[value= 1  1  2  2 [ CPUFloatType{4} ]]()
#   %1072 : Float(1, 290, 48, 36) = onnx::Upsample[mode="nearest"](%1070, %1071) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2512:0
#   %1073 : Float(1, 435, 48, 36) = onnx::Concat[axis=1](%1049, %1072) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/single_person_pose_with_mobilenet.py:54:0
#   %1074 : Float(1, 290, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1073, %refinement_stages.4.trunk.0.decoder1.0.0.weight, %refinement_stages.4.trunk.0.decoder1.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1075 : Float(1, 290, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1074, %refinement_stages.4.trunk.0.decoder1.0.1.weight, %refinement_stages.4.trunk.0.decoder1.0.1.bias, %refinement_stages.4.trunk.0.decoder1.0.1.running_mean, %refinement_stages.4.trunk.0.decoder1.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1076 : Float(1, 290, 48, 36) = onnx::Relu(%1075) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1077 : Float(1, 145, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1076, %refinement_stages.4.trunk.0.decoder1.1.0.weight, %refinement_stages.4.trunk.0.decoder1.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1078 : Float(1, 145, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1077, %refinement_stages.4.trunk.0.decoder1.1.1.weight, %refinement_stages.4.trunk.0.decoder1.1.1.bias, %refinement_stages.4.trunk.0.decoder1.1.1.running_mean, %refinement_stages.4.trunk.0.decoder1.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1079 : Float(1, 145, 48, 36) = onnx::Relu(%1078) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1080 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1079, %refinement_stages.4.trunk.1.initial.0.weight, %refinement_stages.4.trunk.1.initial.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1081 : Float(1, 128, 48, 36) = onnx::Relu(%1080) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1082 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1081, %refinement_stages.4.trunk.1.trunk.0.0.weight, %refinement_stages.4.trunk.1.trunk.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1083 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1082, %refinement_stages.4.trunk.1.trunk.0.1.weight, %refinement_stages.4.trunk.1.trunk.0.1.bias, %refinement_stages.4.trunk.1.trunk.0.1.running_mean, %refinement_stages.4.trunk.1.trunk.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1084 : Float(1, 128, 48, 36) = onnx::Relu(%1083) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1085 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[2, 2], group=1, kernel_shape=[3, 3], pads=[2, 2, 2, 2], strides=[1, 1]](%1084, %refinement_stages.4.trunk.1.trunk.1.0.weight, %refinement_stages.4.trunk.1.trunk.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1086 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1085, %refinement_stages.4.trunk.1.trunk.1.1.weight, %refinement_stages.4.trunk.1.trunk.1.1.bias, %refinement_stages.4.trunk.1.trunk.1.1.running_mean, %refinement_stages.4.trunk.1.trunk.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1087 : Float(1, 128, 48, 36) = onnx::Relu(%1086) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1088 : Float(1, 128, 48, 36) = onnx::Add(%1081, %1087) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/with_mobilenet.py:60:0
#   %1089 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1088, %refinement_stages.4.trunk.2.initial.0.weight, %refinement_stages.4.trunk.2.initial.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1090 : Float(1, 128, 48, 36) = onnx::Relu(%1089) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1091 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1090, %refinement_stages.4.trunk.2.trunk.0.0.weight, %refinement_stages.4.trunk.2.trunk.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1092 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1091, %refinement_stages.4.trunk.2.trunk.0.1.weight, %refinement_stages.4.trunk.2.trunk.0.1.bias, %refinement_stages.4.trunk.2.trunk.0.1.running_mean, %refinement_stages.4.trunk.2.trunk.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1093 : Float(1, 128, 48, 36) = onnx::Relu(%1092) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1094 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[2, 2], group=1, kernel_shape=[3, 3], pads=[2, 2, 2, 2], strides=[1, 1]](%1093, %refinement_stages.4.trunk.2.trunk.1.0.weight, %refinement_stages.4.trunk.2.trunk.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1095 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1094, %refinement_stages.4.trunk.2.trunk.1.1.weight, %refinement_stages.4.trunk.2.trunk.1.1.bias, %refinement_stages.4.trunk.2.trunk.1.1.running_mean, %refinement_stages.4.trunk.2.trunk.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1096 : Float(1, 128, 48, 36) = onnx::Relu(%1095) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1097 : Float(1, 128, 48, 36) = onnx::Add(%1090, %1096) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/with_mobilenet.py:60:0
#   %1098 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1097, %refinement_stages.4.trunk.3.initial.0.weight, %refinement_stages.4.trunk.3.initial.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1099 : Float(1, 128, 48, 36) = onnx::Relu(%1098) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1100 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1099, %refinement_stages.4.trunk.3.trunk.0.0.weight, %refinement_stages.4.trunk.3.trunk.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1101 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1100, %refinement_stages.4.trunk.3.trunk.0.1.weight, %refinement_stages.4.trunk.3.trunk.0.1.bias, %refinement_stages.4.trunk.3.trunk.0.1.running_mean, %refinement_stages.4.trunk.3.trunk.0.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1102 : Float(1, 128, 48, 36) = onnx::Relu(%1101) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1103 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[2, 2], group=1, kernel_shape=[3, 3], pads=[2, 2, 2, 2], strides=[1, 1]](%1102, %refinement_stages.4.trunk.3.trunk.1.0.weight, %refinement_stages.4.trunk.3.trunk.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1104 : Float(1, 128, 48, 36) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1103, %refinement_stages.4.trunk.3.trunk.1.1.weight, %refinement_stages.4.trunk.3.trunk.1.1.bias, %refinement_stages.4.trunk.3.trunk.1.1.running_mean, %refinement_stages.4.trunk.3.trunk.1.1.running_var) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1670:0
#   %1105 : Float(1, 128, 48, 36) = onnx::Relu(%1104) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1106 : Float(1, 128, 48, 36) = onnx::Add(%1099, %1105) # /Users/rwilmar/Downloads/Pose_estimation_3d/models/single-human-pose-estimation-0001/models/with_mobilenet.py:60:0
#   %1107 : Float(1, 128, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1106, %refinement_stages.4.heatmaps.0.0.weight, %refinement_stages.4.heatmaps.0.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   %1108 : Float(1, 128, 48, 36) = onnx::Relu(%1107) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:912:0
#   %1109 : Float(1, 17, 48, 36) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1108, %refinement_stages.4.heatmaps.1.0.weight, %refinement_stages.4.heatmaps.1.0.bias) # /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:342:0
#   return (%output, %865, %926, %987, %1048, %1109)
